# %% [markdown]
# # Big Data (UNT) -  2024
#
# ## Trabajo Práctico 1 - Parte 2

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar debidamente documentado comentado (utilizando #) para que tanto los docentes como sus compañeros puedan comprender el código fácilmente.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Viernes 19 de septiembre a las 13:00 hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub llamado “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 deben estar dentro de esa carpeta.
# - También deben enviar el link de su repositorio -para que pueda ser clonado y corregido- en el canal de Slack #TP-entregas
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No envien el correo hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar. Debido a que se pueden tomar hasta 3 días de extensión a lo largo del curso, no se corregirán sus tareas hasta no recibir el correo.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.

# %% [markdown]
# ### Parte A

# %% [markdown]
# #### Ejercicio 1
# Usando la API de Mercado Libre, obtener los ítems de una consulta de búsqueda. Pueden buscar cualquier producto de su interés.

# %%
# Resolver acá
import requests
import pandas as pd

# %%
buscar = "remeras seleccion argentina 2024"
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20"))

# Hacemos el pedido o request y obtenemos la response
response = requests.request("GET", url)
print(response) # correcto

# Vemos el texto
response.text
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","query":"remeras seleccion argentina 2024","paging":{"total":134,"primary_results":34,"offset":0,"limit":50},"results":[{"id":"MLA1889245008","title":"Camiseta Seleccion Argentina Mundial 2022 Gold Algodon","condition":"new","thumbnail_id":"759049-MLA78591769461_082024","catalog_product_id":null,"listing_type_id":"gold_special","sanitized_title":"camiseta-seleccion-argentina-mundial-2022-gold-algodon","permalink":"https://articulo.mercadolibre.com.ar/MLA-1889245008-camiseta-seleccion-argentina-mundial-2022-gold-algodon-_JM","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA1286","domain_id":"MLA-FOOTBALL_SHIRTS","variation_id":"181444066164","thumbnail":"http://http2.mlstatic.com/D_759049-MLA78591769461_082024-O.jpg","currency_id":"ARS","order_backend":1,"price":36990,"original_price":null,"sale_price":{"price_id":"","amount":36990,"conditions":{"eligible":true,"context_restrictions":[],"start_time":null,"end_time":null},"currency_id":"ARS","exchange_rate":null,"payment_method_prices":[],"payment_method_type":"TMP","regular_amount":null,"type":"standard","metadata":{}},"available_quantity":200,"official_store_id":null,"use_thumbnail_id":false,"accepts_mercadopago":true,"variation_filters":["COLOR","PLAYER","SIZE"],"shipping":{"store_pick_up":false,"free_shipping":true,"logistic_type":"cross_docking","mode":"me2","tags":["self_service_out","mandatory_free_shipping","self_service_available"],"benefits":null,"promise":null,"shipping_score":-1},"stop_time":"2044-08-16T04:00:00.000Z","seller":{"id":462384402,"nickname":"VINIL REMERAS"},"attributes":[{"id":"AGE_GROUP","name":"Edad","value_id":"6725189","value_name":"Adultos","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"6725189","name":"Adultos","struct":null,"source":2579503448603610}],"source":2579503448603610,"value_type":"list"},{"id":"BRAND","name":"Marca","value_id":null,"value_name":"Algebra remeras","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"Algebra remeras","struct":null,"source":6402814585011704}],"source":6402814585011704,"value_type":"string"},{"id":"FILTRABLE_GENDER","name":"Género filtrables","value_id":"18549360","value_name":"Hombre","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"18549360","name":"Hombre","struct":null,"source":2579503448603610}],"source":2579503448603610,"value_type":"list"},{"id":"GENDER","name":"Género","value_id":"339666","value_name":"Hombre","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"339666","name":"Hombre","struct":null,"source":6402814585011704}],"source":6402814585011704,"value_type":"list"},{"id":"IS_EMERGING_BRAND","name":"Es marca emergente","value_id":"242084","value_name":"No","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"242084","name":"No","struct":null,"source":2579503448603610}],"source":2579503448603610,"value_type":"boolean"},{"id":"IS_HIGHLIGHT_BRAND","name":"Es marca destacada","value_id":"242084","value_name":"No","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"242084","name":"No","struct":null,"source":2579503448603610}],"source":2579503448603610,"value_type":"boolean"},{"id":"IS_TOM_BRAND","name":"Es marca TOM","value_id":"242084","value_name":"No","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"242084","name":"No","struct":null,"source":2579503448603610}],"source":2579503448603610,"value_type":"boolean"},{"id":"ITEM_CONDITION","name":"Condición del ítem","value_id":"2230284","value_name":"Nuevo","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2230284","name":"Nuevo","struct":null,"source":6402814585011704}],"source":6402814585011704,"valu ...

# %%
url
# Out:
# 'https://api.mercadolibre.com/sites/MLA/search?q=remeras%20seleccion%20argentina%202024'

# %%
# Pero podríamos guardar el resultado en un diccionario (json)
data = response.json()
#type(data) # dict
data
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'remeras seleccion argentina 2024',
#  'paging': {'total': 134, 'primary_results': 34, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLA1889245008',
#    'title': 'Camiseta Seleccion Argentina Mundial 2022 Gold Algodon',
#    'condition': 'new',
#    'thumbnail_id': '759049-MLA78591769461_082024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'camiseta-seleccion-argentina-mundial-2022-gold-algodon',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1889245008-camiseta-seleccion-argentina-mundial-2022-gold-algodon-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1286',
#    'domain_id': 'MLA-FOOTBALL_SHIRTS',
#    'variation_id': '181444066164',
#    'thumbnail': 'http://http2.mlstatic.com/D_759049-MLA78591769461_082024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 36990,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 36990,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 200,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR', 'PLAYER', 'SIZE'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_out',
#      'mandatory_free_shipping',
#      'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-08-16T04:00:00.000Z',
#    'seller': {'id': 462384402, 'nickname': 'VINIL REMERAS'},
#    'attributes': [{'id': 'AGE_GROUP',
#      'name': 'Edad',
#      'value_id': '6725189',
#      'value_name': 'Adultos',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '6725189',
#        'name': 'Adultos',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'Algebra remeras',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Algebra remeras',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '339666',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '339666',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'IS_EMERGING_BRAND',
#      'name': 'Es marca emergente',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_HIGHLIGHT_BRAND',
#      'name': 'Es marca destacada',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_TOM_BRAND',
#      'name': 'Es marca TOM',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'}],
#    'variations_data': {'181444066164': {'thumbnail': 'http://http2.mlstatic.com/D_759049-MLA78591769461_082024-O.jpg',
#      'ratio': '0.64',
#      'name': 'negro sin numero',
#      'pictures_qty': 3,
#      'price': 36990,
#      'user_product_id': 'MLAU596750191',
#      'attributes': []},
#     '181444066166': {'thumbnail': 'http://http2.mlstatic.com/D_759049-MLA78591769461_082024-O.jpg',
#      'ratio': '0.64',
#      'name': 'negro sin numero',
#      'pictures_qty': 3,
#      'price': 36990,
#      'user_product_id': 'MLAU596748701',
#      'attributes': []},
#     '181444066168': {'thumbnail': 'http://http2.mlstatic.com/D_759049-MLA78591769461_082024-O.jpg',
#      'ratio': '0.64',
#      'name': 'negro sin numero',
#      'pictures_qty': 3,
#      'price': 36990,
#      'user_product_id': 'MLAU599219306',
#      'attributes': []},
#     '181444066170': {'thumbnail': 'http://http2.mlstatic.com/D_759049-MLA78591769461_082024-O.jpg',
#      'ratio': '0.64',
#      'name': 'negro sin numero',
#      'pictures_qty': 3,
#      'price': 36990,
#      'user_product_id': 'MLAU599219310',
#      'attributes': []},
#     '181444066172': {'thumbnail': 'http://http2.mlstatic.com/D_759049-MLA78591769461_082024-O.jpg',
#      'ratio': '0.64',
#      'name': 'negro sin numero',
#      'pictures_qty': 3,
#      'price': 36990,
#      'user_product_id': 'MLAU599226232',
#      'attributes': []}},
#    'installments': {'quantity': 6,
#     'amount': 8503.38,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1874874572',
#    'title': 'Remera Argentina Campeón Copa América 2024 - Afa Selección',
#    'condition': 'new',
#    'thumbnail_id': '679274-MLA78002397384_082024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'remera-argentina-campeon-copa-america-2024-afa-seleccion',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1874874572-remera-argentina-campeon-copa-america-2024-afa-seleccion-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA7096',
#    'domain_id': 'MLA-SPORT_T_SHIRTS',
#    'variation_id': '184103650667',
#    'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 18999,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 18999,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 500,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR', 'FABRIC_DESIGN', 'SIZE'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-08-01T04:00:00.000Z',
#    'seller': {'id': 361175316, 'nickname': 'MAA_INDUMENTARIA'},
#    'attributes': [{'id': 'AGE_GROUP',
#      'name': 'Edad',
#      'value_id': '6725189',
#      'value_name': 'Adultos',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '6725189',
#        'name': 'Adultos',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'MA_INDUMENTARIA',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'MA_INDUMENTARIA',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': None,
#      'value_name': 'Hombre,Mujer,Niñas,Niños',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 2579503448603610},
#       {'id': '18549361',
#        'name': 'Mujer',
#        'struct': None,
#        'source': 2579503448603610},
#       {'id': '18549362',
#        'name': 'Niñas',
#        'struct': None,
#        'source': 2579503448603610},
#       {'id': '18549363',
#        'name': 'Niños',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '110461',
#      'value_name': 'Sin género',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '110461',
#        'name': 'Sin género',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'IS_EMERGING_BRAND',
#      'name': 'Es marca emergente',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_HIGHLIGHT_BRAND',
#      'name': 'Es marca destacada',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_TOM_BRAND',
#      'name': 'Es marca TOM',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'REMERAS / FÚTBOL / JUGADORES / CLUBES',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'REMERAS / FÚTBOL / JUGADORES / CLUBES',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'}],
#    'variations_data': {'184103650671': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591642',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650675': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655315',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650679': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655319',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650733': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655365',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650755': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591720',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650739': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655381',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650743': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591702',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650745': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591706',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650773': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592708',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650685': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655327',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650759': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591728',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650763': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591744',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650775': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591756',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650703': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592632',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650715': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592648',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650731': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655363',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650737': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655375',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650713': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592644',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650693': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592622',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650741': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592688',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650757': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655393',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650683': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655325',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650701': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591672',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650707': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655337',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650751': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655389',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650699': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591670',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650689': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655329',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650719': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592650',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650669': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655311',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650725': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655359',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650727': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592668',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650735': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592680',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650767': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655401',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650667': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591640',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650771': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655409',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650729': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592674',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650765': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592704',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650769': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655407',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650681': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655323',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650687': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591654',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650697': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592626',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650673': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591646',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650717': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655351',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650749': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592692',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650761': {'thumbnail': 'http://http2.mlstatic.com/D_782370-MLA78227411881_082024-O.jpg',
#      'ratio': '0.86',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591742',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650709': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655341',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650723': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655357',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650753': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591716',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650677': {'thumbnail': 'http://http2.mlstatic.com/D_679274-MLA78002397384_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591650',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}]},
#     '184103650691': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592620',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650695': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655333',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650705': {'thumbnail': 'http://http2.mlstatic.com/D_908478-MLA78227557141_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Celeste',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592634',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Celeste'}]},
#     '184103650711': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU446655347',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]},
#     '184103650747': {'thumbnail': 'http://http2.mlstatic.com/D_872901-MLA78227576853_082024-O.jpg',
#      'ratio': '0.77',
#      'name': 'Blanco',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448591708',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Blanco'}]},
#     '184103650721': {'thumbnail': 'http://http2.mlstatic.com/D_785947-MLA78002397550_082024-O.jpg',
#      'ratio': '1.01',
#      'name': 'Azul marino',
#      'pictures_qty': 4,
#      'price': 18999,
#      'user_product_id': 'MLAU448592654',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Azul marino'}]}},
#    'installments': {'quantity': 6,
#     'amount': 4367.55,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1817084158',
#    'title': 'Lum - Remera Messi Seleccion Argentina 2024 - Algodon 1°',
#    'condition': 'new',
#    'thumbnail_id': '775962-MLA76933588730_062024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'lum-remera-messi-seleccion-argentina-2024-algodon-1',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1817084158-lum-remera-messi-seleccion-argentina-2024-algodon-1-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA109042',
#    'domain_id': 'MLA-T_SHIRTS',
#    'variation_id': '180769296388',
#    'thumbnail': 'http://http2.mlstatic.com/D_775962-MLA76933588730_062024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 17100,
#    'original_price': 18000,
#    'sale_price': {'price_id': '',
#     'amount': 17100,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-09-16T03:00:00Z',
#      'end_time': '2024-09-26T03:00:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 18000,
#     'type': 'promotion',
#     'metadata': {'promotion_id': 'OFFER-MLA1817084158-10178643877',
#      'promotion_type': 'campaign',
#      'campaign_id': 'MLA55381'}},
#    'available_quantity': 100,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR', 'PRINT_DESIGN', 'SIZE'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-06-14T04:00:00.000Z',
#    'seller': {'id': 173057290, 'nickname': 'LUM MISTICO'},
#    'attributes': [{'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': None,
#      'value_name': '1',
#      'attribute_group_id': '',
#      'attribute_group_name': '',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'integer'},
#     {'id': 'AGE_GROUP',
#      'name': 'Edad',
#      'value_id': '6725189',
#      'value_name': 'Adultos',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '6725189',
#        'name': 'Adultos',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '37394154',
#      'value_name': 'Lum Indumentaria',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '37394154',
#        'name': 'Lum Indumentaria',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '339666',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '339666',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'IS_EMERGING_BRAND',
#      'name': 'Es marca emergente',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_HIGHLIGHT_BRAND',
#      'name': 'Es marca destacada',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_TOM_BRAND',
#      'name': 'Es marca TOM',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'MESSI COPA AMERICA',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'MESSI COPA AMERICA',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'SALE_FORMAT',
#      'name': 'Formato de venta',
#      'value_id': '1359391',
#      'value_name': 'Unidad',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '1359391',
#        'name': 'Unidad',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'UNITS_PER_PACK',
#      'name': 'Unidades por pack',
#      'value_id': None,
#      'value_name': '1',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'number'}],
#    'variations_data': {'180769296390': {'thumbnail': 'http://http2.mlstatic.com/D_775962-MLA76933588730_062024-O.jpg',
#      'ratio': '0.85',
#      'name': 'Negro',
#      'pictures_qty': 3,
#      'price': 18000,
#      'user_product_id': 'MLAU390676188',
#      'attributes': []},
#     '180769296392': {'thumbnail': 'http://http2.mlstatic.com/D_775962-MLA76933588730_062024-O.jpg',
#      'ratio': '0.85',
#      'name': 'Negro',
#      'pictures_qty': 3,
#      'price': 18000,
#      'user_product_id': 'MLAU390676190',
#      'attributes': []},
#     '180769296394': {'thumbnail': 'http://http2.mlstatic.com/D_775962-MLA76933588730_062024-O.jpg',
#      'ratio': '0.85',
#      'name': 'Negro',
#      'pictures_qty': 3,
#      'price': 18000,
#      'user_product_id': 'MLAU388983785',
#      'attributes': []},
#     '180769296396': {'thumbnail': 'http://http2.mlstatic.com/D_775962-MLA76933588730_062024-O.jpg',
#      'ratio': '0.85',
#      'name': 'Negro',
#      'pictures_qty': 3,
#      'price': 18000,
#      'user_product_id': 'MLAU390676200',
#      'attributes': []},
#     '180769296388': {'thumbnail': 'http://http2.mlstatic.com/D_775962-MLA76933588730_062024-O.jpg',
#      'ratio': '0.85',
#      'name': 'Negro',
#      'pictures_qty': 3,
#      'price': 18000,
#      'user_product_id': 'MLAU388983779',
#      'attributes': []}},
#    'installments': {'quantity': 6,
#     'amount': 3931,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1835022836',
#    'title': 'Remera Camiseta Los Pumas Le Coq Sportif Home Fan Dep',
#    'condition': 'new',
#    'thumbnail_id': '603498-MLA77467409581_072024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'remera-camiseta-los-pumas-le-coq-sportif-home-fan-dep',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1835022836-remera-camiseta-los-pumas-le-coq-sportif-home-fan-dep-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1286',
#    'domain_id': 'MLA-FOOTBALL_SHIRTS',
#    'variation_id': '180952715870',
#    'thumbnail': 'http://http2.mlstatic.com/D_603498-MLA77467409581_072024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 123990,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 123990,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR', 'SIZE'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'drop_off',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-06-29T04:00:00.000Z',
#    'seller': {'id': 277445428, 'nickname': 'MUNDO FOSCO'},
#    'attributes': [{'id': 'AGE_GROUP',
#      'name': 'Edad',
#      'value_id': '6725189',
#      'value_name': 'Adultos',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '6725189',
#        'name': 'Adultos',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '415941',
#      'value_name': 'Le Coq Sportif',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '415941',
#        'name': 'Le Coq Sportif',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '339666',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '339666',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'IS_EMERGING_BRAND',
#      'name': 'Es marca emergente',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_HIGHLIGHT_BRAND',
#      'name': 'Es marca destacada',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_TOM_BRAND',
#      'name': 'Es marca TOM',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'}],
#    'variations_data': {'180952715870': {'thumbnail': 'http://http2.mlstatic.com/D_603498-MLA77467409581_072024-O.jpg',
#      'ratio': '0.79',
#      'name': 'Blanco Celeste',
#      'pictures_qty': 3,
#      'price': 123990,
#      'user_product_id': 'MLAU399310196',
#      'attributes': [{'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '7790446636828'}]},
#     '180952715864': {'thumbnail': 'http://http2.mlstatic.com/D_603498-MLA77467409581_072024-O.jpg',
#      'ratio': '0.79',
#      'name': 'Blanco Celeste',
#      'pictures_qty': 3,
#      'price': 123990,
#      'user_product_id': 'MLAU397582277',
#      'attributes': [{'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '7790446636811'}]}},
#    'installments': {'quantity': 6,
#     'amount': 28503.23,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1885677556',
#    'title': 'Remera Selección Argentina Original Copa América 2024',
#    'condition': 'new',
#    'thumbnail_id': '759745-MLA78253113170_082024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'remera-seleccion-argentina-original-copa-america-2024',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1885677556-remera-seleccion-argentina-original-copa-america-2024-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1286',
#    'domain_id': 'MLA-FOOTBALL_SHIRTS',
#    'variation_id': '184325062059',
#    'thumbnail': 'http://http2.mlstatic.com/D_759745-MLA78253113170_082024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 5,
#    'price': 88000,
#    'original_price': None,
# ...
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1407684573',
#    'title': 'Camiseta Boca Jr Edicion Golden Algodon Con Numero',
#    'condition': 'new',
#    'thumbnail_id': '868109-MLA74347833466_022024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'camiseta-boca-jr-edicion-golden-algodon-con-numero',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1407684573-camiseta-boca-jr-edicion-golden-algodon-con-numero-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1286',
#    'domain_id': 'MLA-FOOTBALL_SHIRTS',
#    'variation_id': '182269356475',
#    'thumbnail': 'http://http2.mlstatic.com/D_868109-MLA74347833466_022024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 50,
#    'price': 30171.5,
#    'original_price': 33523.89,
#    'sale_price': {'price_id': '',
#     'amount': 30171.5,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': '2024-09-01T03:54:26Z',
#      'end_time': '2024-10-01T02:50:00Z'},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': 33523.89,
#     'type': 'promotion',
#     'metadata': {'campaign_discount_percentage': 10,
#      'campaign_end_date': '2024-10-01T02:50:00Z',
#      'campaign_id': 'P-MLA14209002',
#      'discount_meli_amount': 335.24,
#      'funding_mode': 'coupon',
#      'promotion_type': 'marketplace_campaign',
#      'variation': '51580',
#      'experiment_id': 'cm_med_uplift_P-MLA14209002',
#      'order_item_price': 30506.74,
#      'promotion_id': 'OFFER-MLA1407684573-10169422308'}},
#    'available_quantity': 250,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR', 'PLAYER', 'SIZE'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['self_service_out',
#      'mandatory_free_shipping',
#      'self_service_available'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-02-03T04:00:00.000Z',
#    'seller': {'id': 462384402, 'nickname': 'VINIL REMERAS'},
#    'attributes': [{'id': 'AGE_GROUP',
#      'name': 'Edad',
#      'value_id': '6725189',
#      'value_name': 'Adultos',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '6725189',
#        'name': 'Adultos',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'Algebra remeras',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Algebra remeras',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'FILTRABLE_GENDER',
#      'name': 'Género filtrables',
#      'value_id': '18549360',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '18549360',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'list'},
#     {'id': 'GENDER',
#      'name': 'Género',
#      'value_id': '339666',
#      'value_name': 'Hombre',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '339666',
#        'name': 'Hombre',
#        'struct': None,
#        'source': 7571550481372610}],
#      'source': 7571550481372610,
#      'value_type': 'list'},
#     {'id': 'IS_EMERGING_BRAND',
#      'name': 'Es marca emergente',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_HIGHLIGHT_BRAND',
#      'name': 'Es marca destacada',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'IS_TOM_BRAND',
#      'name': 'Es marca TOM',
#      'value_id': '242084',
#      'value_name': 'No',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '242084',
#        'name': 'No',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'boolean'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'}],
#    'variations_data': {'182269356475': {'thumbnail': 'http://http2.mlstatic.com/D_868109-MLA74347833466_022024-O.jpg',
#      'ratio': '0.64',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 33523.89,
#      'user_product_id': 'MLAU347460307',
#      'attributes': []},
#     '181691913769': {'thumbnail': 'http://http2.mlstatic.com/D_868109-MLA74347833466_022024-O.jpg',
#      'ratio': '0.64',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 33523.89,
#      'user_product_id': 'MLAU280987821',
#      'attributes': []},
#     '181691297393': {'thumbnail': 'http://http2.mlstatic.com/D_780764-MLA74347841346_022024-O.jpg',
#      'ratio': '0.76',
#      'name': 'Negro',
#      'pictures_qty': 1,
#      'price': 33523.89,
#      'user_product_id': 'MLAU282105482',
#      'attributes': []},
#     '181691913771': {'thumbnail': 'http://http2.mlstatic.com/D_868109-MLA74347833466_022024-O.jpg',
#      'ratio': '0.64',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 33523.89,
#      'user_product_id': 'MLAU282273082',
#      'attributes': []},
#     '181691913773': {'thumbnail': 'http://http2.mlstatic.com/D_868109-MLA74347833466_022024-O.jpg',
#      'ratio': '0.64',
#      'name': 'Negro',
#      'pictures_qty': 4,
#      'price': 33523.89,
#      'user_product_id': 'MLAU280993315',
#      'attributes': []}},
#    'installments': {'quantity': 6,
#     'amount': 6935.92,
#     'rate': 37.93,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None}],
#  'sort': {'id': 'relevance', 'name': 'Más relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor precio'},
#   {'id': 'price_desc', 'name': 'Mayor precio'}],
#  'filters': [],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Tiendas oficiales',
#    'type': 'text',
#    'values': [{'id': 'all',
#      'name': 'Todas las tiendas oficiales',
#      'results': 7},
#     {'id': '74482', 'name': 'ATON SHOP', 'results': 2},
#     {'id': '55801', 'name': 'BSfit', 'results': 2},
#     {'id': '2087', 'name': 'Punto Deportivo', 'results': 1},
#     {'id': '2381', 'name': 'Outlet Deportivo Oficial', 'results': 1}]},
#   {'id': 'category',
#    'name': 'Categorías',
#    'type': 'text',
#    'values': [{'id': 'MLA1285', 'name': 'Fútbol', 'results': 69},
#     {'id': 'MLA109042',
#      'name': 'Remeras, Musculosas y Chombas',
#      'results': 43},
#     {'id': 'MLA109278', 'name': 'Ropa Interior y de Dormir', 'results': 15},
#     {'id': 'MLA417397', 'name': 'Ropa Deportiva', 'results': 3},
#     {'id': 'MLA1362', 'name': 'Camping, Caza y Pesca', 'results': 1},
#     {'id': 'MLA37856', 'name': 'Handball', 'results': 1},
#     {'id': 'MLA1499', 'name': 'Industrias y Oficinas', 'results': 1},
#     {'id': 'MLA1333', 'name': 'Voley', 'results': 1}]},
#   {'id': 'discount',
#    'name': 'Descuentos',
#    'type': 'number',
#    'values': [{'id': '5-100', 'name': 'Desde 5% OFF', 'results': 25},
#     {'id': '10-100', 'name': 'Desde 10% OFF', 'results': 7},
#     {'id': '30-100', 'name': 'Desde 30% OFF', 'results': 3},
#     {'id': '40-100', 'name': 'Desde 40% OFF', 'results': 1}]},
#   {'id': 'state',
#    'name': 'Ubicación',
#    'type': 'text',
#    'values': [{'id': 'TUxBUENBUGw3M2E1',
#      'name': 'Capital Federal',
#      'results': 50},
#     {'id': 'TUxBUEdSQWVmNTVm', 'name': 'Bs.As. G.B.A. Oeste', 'results': 28},
#     {'id': 'TUxBUEdSQWU4ZDkz', 'name': 'Bs.As. G.B.A. Norte', 'results': 23},
#     {'id': 'TUxBUEdSQXJlMDNm', 'name': 'Bs.As. G.B.A. Sur', 'results': 12},
#     {'id': 'TUxBUENPUmFkZGIw', 'name': 'Córdoba', 'results': 9},
#     {'id': 'TUxBUE1FTmE5OWQ4', 'name': 'Mendoza', 'results': 4},
#     {'id': 'TUxBUFNBTm5lYjU4', 'name': 'San Juan', 'results': 1},
#     {'id': 'TUxBUFNBTmU5Nzk2', 'name': 'Santa Fe', 'results': 1}]},
#   {'id': 'price',
#    'name': 'Precio',
#    'type': 'range',
#    'values': [{'id': '*-20000.0', 'name': 'Hasta $ 20.000', 'results': 42},
#     {'id': '20000.0-25000.0', 'name': '$20.000 a $25.000', 'results': 57},
#     {'id': '25000.0-*', 'name': 'Más de $25.000', 'results': 57}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con MercadoPago', 'results': 134}]},
#   {'id': 'installments',
#    'name': 'Financiación',
#    'type': 'text',
#    'values': [{'id': 'yes', 'name': 'En cuotas', 'results': 134},
#     {'id': 'no_interest', 'name': 'Sin interés', 'results': 6}]},
#   {'id': 'shipping',
#    'name': 'Envío',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envíos',
#      'results': 134},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 2}]},
#   {'id': 'power_seller',
#    'name': 'Filtro por calidad de vendedores',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Mejores vendedores', 'results': 113}]},
#   {'id': 'since',
#    'name': 'Filtro por fecha de comienzo',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Publicados hoy', 'results': 2}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicaciones con imágenes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con fotos', 'results': 134}]},
#   {'id': 'all_payment_methods_discount',
#    'name': 'Descuentos para todos los medios de pago',
#    'type': 'number',
#    'values': [{'id': '10-100', 'name': 'Desde 10% OFF', 'results': 5},
#     {'id': '30-100', 'name': 'Desde 30% OFF', 'results': 3}]},
#   {'id': 'price_campaign_id',
#    'name': 'Campaña',
#    'type': 'number',
#    'values': [{'id': 'MLA55381', 'name': 'MLA55381', 'results': 5},
#     {'id': 'MLA55008', 'name': 'MLA55008', 'results': 4},
#     {'id': 'P-MLA14209002', 'name': 'P-MLA14209002', 'results': 4}]},
#   {'id': 'shipping_cost',
#    'name': 'Costo de envío',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 46}]},
#   {'id': 'AGE_GROUP',
#    'name': 'Edad',
#    'type': 'STRING',
#    'values': [{'id': '6725189', 'name': 'Adultos', 'results': 104},
#     {'id': '1065183', 'name': 'Niños', 'results': 30}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '37394154', 'name': 'Lum Indumentaria', 'results': 11},
#     {'id': '13079579', 'name': 'Artemix Argentina', 'results': 9},
#     {'id': '276243', 'name': 'Genérica', 'results': 6},
#     {'id': '15784', 'name': 'Kappa', 'results': 6},
#     {'id': '415941', 'name': 'Le Coq Sportif', 'results': 4},
#     {'id': '12914027', 'name': 'Jaia', 'results': 4},
#     {'id': '12047922', 'name': 'MGR', 'results': 4},
#     {'id': '35914350', 'name': 'Illa Inti', 'results': 3},
#     {'id': '915398', 'name': 'Denver', 'results': 2},
#     {'id': '7206870', 'name': 'Payo', 'results': 2},
#     {'id': '6880366', 'name': 'Icaro', 'results': 2},
#     {'id': '4646225', 'name': 'DRB', 'results': 2},
#     {'id': '415939', 'name': 'Hummel', 'results': 2},
#     {'id': '35982983', 'name': 'Irarte', 'results': 2},
#     {'id': '34621569', 'name': 'Lyostore', 'results': 2},
#     {'id': '18854601', 'name': 'Tienda Uke', 'results': 2},
#     {'id': '14810', 'name': 'adidas', 'results': 2},
#     {'id': '995663', 'name': 'BM', 'results': 1},
#     {'id': '560300', 'name': 'Boca Juniors', 'results': 1},
#     {'id': '5166328', 'name': 'ADN', 'results': 1},
#     {'id': '4403709', 'name': 'Independiente', 'results': 1},
#     {'id': '40456296', 'name': 'OMG!', 'results': 1},
#     {'id': '37693088', 'name': 'River', 'results': 1},
#     {'id': '34882511', 'name': 'Maldito Paparazzo', 'results': 1},
#     {'id': '3037463', 'name': 'River Plate', 'results': 1},
#     {'id': '2786557', 'name': 'Racing', 'results': 1},
#     {'id': '27264641', 'name': 'Danitex', 'results': 1},
#     {'id': '13210919', 'name': 'Omaigat', 'results': 1}]},
#   {'id': 'FILTRABLE_GENDER',
#    'name': 'Género',
#    'type': 'STRING',
#    'values': [{'id': '18549360', 'name': 'Hombre', 'results': 97},
#     {'id': '18549361', 'name': 'Mujer', 'results': 40},
#     {'id': '18549363', 'name': 'Niños', 'results': 34},
#     {'id': '18549362', 'name': 'Niñas', 'results': 13}]},
#   {'id': 'FILTRABLE_SIZE',
#    'name': 'Talle',
#    'type': 'STRING',
#    'values': [{'id': '12917787', 'name': 'XL', 'results': 91},
#     {'id': '12917802', 'name': 'L', 'results': 87},
#     {'id': '12917795', 'name': 'M', 'results': 83},
#     {'id': '12917796', 'name': 'S', 'results': 80},
#     {'id': '12917846', 'name': '2XL', 'results': 78},
#     {'id': '12917776', 'name': 'XS', 'results': 45},
#     {'id': '12917837', 'name': '3XL', 'results': 44},
#     {'id': '12917836', 'name': '2XS', 'results': 24},
#     {'id': '12917843', 'name': '4XL', 'results': 21},
#     {'id': '12917835', 'name': '3XS', 'results': 14},
#     {'id': '12189481', 'name': '12 años', 'results': 11},
#     {'id': '12917838', 'name': '6XL', 'results': 6},
#     {'id': '12189469', 'name': '6 años', 'results': 3},
#     {'id': '12917842', 'name': '5XL', 'results': 2},
#     {'id': '12189485', 'name': '14 años', 'results': 2},
#     {'id': '12189477', 'name': '10 años', 'results': 2},
#     {'id': '12189473', 'name': '8 años', 'results': 2},
#     {'id': '12189465', 'name': '4 años', 'results': 2},
#     {'id': '12189471', 'name': '7 años', 'results': 1},
#     {'id': '12189461', 'name': '2 años', 'results': 1}]},
#   {'id': 'IS_HIGHLIGHT_BRAND',
#    'name': 'Marca destacada',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es marca destacada', 'results': 5}]},
#   {'id': 'IS_SPORTIVE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es deportivo', 'results': 4}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'results': 132},
#     {'id': '2230581', 'name': 'Usado', 'results': 2}]},
#   {'id': 'MAIN_MATERIAL',
#    'name': 'Material principal',
#    'type': 'STRING',
#    'values': [{'id': '466793', 'name': 'Algodón', 'results': 42},
#     {'id': '466794', 'name': 'Poliéster', 'results': 6},
#     {'id': '3568029', 'name': 'Modal', 'results': 2},
#     {'id': '462325', 'name': 'Polar', 'results': 1}]},
#   {'id': 'SLEEVE_TYPE',
#    'name': 'Tipo de manga',
#    'type': 'STRING',
#    'values': [{'id': '466804', 'name': 'Corta', 'results': 42},
#     {'id': '1189474', 'name': 'Sin manga', 'results': 2}]},
#   {'id': 'WITH_RECYCLED_MATERIALS',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con materiales reciclados',
#      'results': 2}]}],
#  'pdp_tracking': {'group': False, 'product_info': []},
#  'user_context': None}

# %% [markdown]
# #### Ejercicio 2
# #Guarden los precios de los ítems obtenidos en un dataframe y calculen el precio promedio, el mínimo y el máximo.

# %%
# Resolver acá
precios = [item['price'] for item in data['results']]
df_precios = pd.DataFrame(precios, columns=['precio'])

# Calcular estadísticas descriptivas
print(df_precios.describe())
# Out:
#               precio
# count      50.000000
# mean    31186.183800
# std     24373.160092
# min      3229.050000
# 25%     18000.000000
# 50%     22499.000000
# 75%     31535.375000
# max    123990.000000

# %% [markdown]
# #### Ejercicio 3
# Armen un histograma de los precios. ¿Ven algún <i>outlier<i>?
# Nota: pueden usar la librería de Matplotlib o la de Pandas.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Resolver acá

plt.hist(df_precios['precio'], bins=10, edgecolor='black')
plt.xlabel('Precio')
plt.ylabel('Cantidad')
plt.title('Distribución de precios de remeras Selección Argentina 2024')
plt.show()

# %% [markdown]
# #### Ejercicio 4
# Realicen alguna consulta adicional utilizando la API de Mercado Libre (debe ser alguna consulta que no se haya visto en clase. Por ejemplo, obtener los ítems de un vendedor en particular, obtener los productos de una categoría u otros). Analicen los resultados y comenten uno o dos que les parezcan interesantes (por ejemplo, precios promedio de los productos de un vendedor, diferencia entre el precio original y actual, si acepta mercado pago para la compra de productos, etc.)

# %%
# Resolver acá

# %% [markdown]
# ### Parte B

# %% [markdown]
# #### Ejercicio 5
# De la página de noticias del [diario La Nación](https://www.lanacion.com.ar/), utilicen herramientas de web scraping para obtener los links de las noticias de la portada. Guarden los links obtenidos en un dataframe y expórtenlo a un archivo de excel.
#
# Nota 1: es posible que logren obtener los links a las noticias sin el dominio: "https://www.lanacion.com.ar/". De ser así, concatenen el dominio a la ruta del link obtenido, tal que se obtenga un link al que se pueda acceder. Es decir, que las cadenas de caracteres finales tendrán la forma: https://www.lanacion.com.ar/*texto_obtenido*)
#
# Nota 2: junto con su entrega, adjunten una captura de la página de noticias al momento de correr su código. Eso servirá al momento de la corrección para verificar que los links obtenidos hacen referencia a las noticias de ese día y hora.

# %%
# Resolver acá
